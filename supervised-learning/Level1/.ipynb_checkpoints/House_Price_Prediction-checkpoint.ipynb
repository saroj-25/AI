# %% [markdown]
# ## **House price Prediction**
#
# **Project for Prediction of House price and complete analaysis**
#
# **Dataset Description**
#
# - **Title** : Ames Housing Dataset (Contains the data on residential homes sold in AMes, lowa from 2006 to 2010)
#
# - **Data Samples** : 1460
#
# - **Features** : 80 features
#
# - **Target Column** : The Price Column

# %% [markdown]
# #### **1. Importing Libarary and loading dataset**

# %% [markdown]
# # import core libraries
#
# import pandas as pd
# import numpy as np
# imprt matplotlib.pyplot as plt
# import seaborn as sns
#
# # import machine learning tools
#
# from sklearn.model_selec

# %%
print("hello")
# Out:
# hello
